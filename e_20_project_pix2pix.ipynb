# %% [markdown]
# # 데이터 로드 및 확인

# %%
# 데이터 불러오기
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
# 학습용 데이터셋 시각화
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 데이터 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %% [markdown]
# # 이미지 분할

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# # Augmentation 적용

# %% [markdown]
# ## apply_augmentation

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
# apply_augmentation를 적용한 데이터 시각화
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
# 학습 데이터 적용 및 시각화
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# # Generator 구성

# %% [markdown]
# ## Encoder 구성

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

print("✅")
# Out:
# ✅

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %% [markdown]
# ## Encoder 레이어 구성 확인

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ## Decoder 구성

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,256)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
print("✅")
# Out:
# ✅

# %% [markdown]
# ## Decoder 레이어 구성 확인

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 256)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         2099200
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 17,445,632
# Trainable params: 17,440,640
# Non-trainable params: 4,992
# _________________________________________________________________

# %% [markdown]
# ##  EncoderDecoderGenerator 구성

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %% [markdown]
# # U-Net Generator 구성

# %% [markdown]
# ## U-Net EncodeBlock 및 DecodeBlock 구성

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %% [markdown]
# ## U-Net Generator 구성

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %% [markdown]
# ## U-Net Generator 레이어 구성 확인

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # Discriminator 구성

# %% [markdown]
# ## Discriminator Block 구성

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %% [markdown]
# ## 출력 크기 확인

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# ## Discriminator 구성

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %% [markdown]
# ## Discriminator 레이어 구성 확인

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# 시각화
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # 학습 및 테스트

# %% [markdown]
# ## 손실함수 생성

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %% [markdown]
# ## optimizer 생성

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %% [markdown]
# ## train_step 구성

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %% [markdown]
# ## 모델 학습

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9247
# L1_loss:0.4316
# Discriminator_loss:1.3520
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.6159
# L1_loss:0.3331
# Discriminator_loss:1.0325
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.3463
# L1_loss:0.2666
# Discriminator_loss:0.7079
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.4734
# L1_loss:0.2725
# Discriminator_loss:0.6219
#
# EPOCH[1] - STEP[50]
# Generator_loss:2.0935
# L1_loss:0.2616
# Discriminator_loss:0.5173
#
# EPOCH[1] - STEP[60]
# Generator_loss:0.7671
# L1_loss:0.2556
# Discriminator_loss:1.1034
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.4931
# L1_loss:0.2133
# Discriminator_loss:1.1817
#
# EPOCH[1] - STEP[80]
# Generator_loss:2.5597
# L1_loss:0.2182
# Discriminator_loss:0.6510
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.2468
# L1_loss:0.2359
# Discriminator_loss:1.3795
#
# EPOCH[1] - STEP[100]
# Generator_loss:0.9249
# L1_loss:0.2327
# Discriminator_loss:0.8379
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.7601
# L1_loss:0.2461
# Discriminator_loss:0.6939
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.0581
# L1_loss:0.2390
# Discriminator_loss:1.2807
#
# EPOCH[1] - STEP[130]
# Generator_loss:2.1026
# L1_loss:0.2866
# Discriminator_loss:0.5230
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.8737
# L1_loss:0.3077
# Discriminator_loss:0.7666
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.4579
# L1_loss:0.1930
# Discriminator_loss:1.2154
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.3352
# L1_loss:0.2344
# Discriminator_loss:0.3414
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.0834
# L1_loss:0.2299
# Discriminator_loss:0.7945
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.2524
# L1_loss:0.2543
# Discriminator_loss:0.5607
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.8128
# L1_loss:0.2220
# Discriminator_loss:0.2032
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.1360
# L1_loss:0.2475
# Discriminator_loss:0.5842
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.9392
# L1_loss:0.3156
# Discriminator_loss:0.3297
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.6624
# L1_loss:0.3026
# Discriminator_loss:0.5871
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.9454
# L1_loss:0.2217
# Discriminator_loss:0.4597
#
# EPOCH[1] - STEP[240]
# Generator_loss:2.2104
# L1_loss:0.1600
# Discriminator_loss:0.7566
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.4585
# L1_loss:0.2366
# Discriminator_loss:0.5593
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.5665
# L1_loss:0.2357
# Discriminator_loss:0.6657
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.0914
# L1_loss:0.1866
# Discriminator_loss:0.9234
#
# EPOCH[2] - STEP[30]
# Generator_loss:2.0150
# L1_loss:0.2629
# Discriminator_loss:0.5496
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.3995
# L1_loss:0.2220
# Discriminator_loss:0.6920
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.9591
# L1_loss:0.1929
# Discriminator_loss:2.3697
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.0940
# L1_loss:0.2473
# Discriminator_loss:0.2790
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.9377
# L1_loss:0.2382
# Discriminator_loss:0.7302
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.6154
# L1_loss:0.2279
# Discriminator_loss:0.4476
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.8501
# L1_loss:0.2006
# Discriminator_loss:0.4918
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.7198
# L1_loss:0.2156
# Discriminator_loss:1.4292
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.9435
# L1_loss:0.1961
# Discriminator_loss:0.5499
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.5964
# L1_loss:0.2041
# Discriminator_loss:0.6421
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.9214
# L1_loss:0.2285
# Discriminator_loss:0.4841
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.6447
# L1_loss:0.1566
# Discriminator_loss:0.3931
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.4911
# L1_loss:0.2218
# Discriminator_loss:0.4478
#
# EPOCH[2] - STEP[160]
# Generator_loss:2.7541
# L1_loss:0.2047
# Discriminator_loss:0.5371
#
# EPOCH[2] - STEP[170]
# Generator_loss:3.3410
# L1_loss:0.1868
# Discriminator_loss:1.2635
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.3420
# L1_loss:0.1794
# Discriminator_loss:0.5322
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.7638
# L1_loss:0.2370
# Discriminator_loss:0.5145
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.7145
# L1_loss:0.1952
# Discriminator_loss:0.3910
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.5457
# L1_loss:0.1814
# Discriminator_loss:0.6386
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.8549
# L1_loss:0.2511
# Discriminator_loss:0.3061
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.2134
# L1_loss:0.2140
# Discriminator_loss:0.6465
#
# EPOCH[2] - STEP[240]
# Generator_loss:2.0308
# L1_loss:0.2274
# Discriminator_loss:0.4580
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.3332
# L1_loss:0.2280
# Discriminator_loss:0.5159
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.6105
# L1_loss:0.2130
# Discriminator_loss:0.3669
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.0462
# L1_loss:0.1854
# Discriminator_loss:0.6388
#
# EPOCH[3] - STEP[30]
# Generator_loss:2.4875
# L1_loss:0.1834
# Discriminator_loss:0.5826
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.6049
# L1_loss:0.2167
# Discriminator_loss:0.4007
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.7329
# L1_loss:0.2447
# Discriminator_loss:0.4552
#
# EPOCH[3] - STEP[60]
# Generator_loss:0.3916
# L1_loss:0.2025
# Discriminator_loss:1.6830
# EPOCH[3] - STEP[70]
# Generator_loss:0.8454
# L1_loss:0.2036
# Discriminator_loss:0.9694
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.8199
# L1_loss:0.2006
# Discriminator_loss:0.9031
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.4771
# L1_loss:0.1946
# Discriminator_loss:0.7695
#
# EPOCH[3] - STEP[100]
# Generator_loss:0.9759
# L1_loss:0.2414
# Discriminator_loss:0.6811
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.4177
# L1_loss:0.2727
# Discriminator_loss:0.5651
#
# EPOCH[3] - STEP[120]
# Generator_loss:0.9950
# L1_loss:0.1625
# Discriminator_loss:0.8467
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.1047
# L1_loss:0.1810
# Discriminator_loss:0.8046
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.2962
# L1_loss:0.1900
# Discriminator_loss:0.9780
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.8576
# L1_loss:0.1920
# Discriminator_loss:0.6640
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.1441
# L1_loss:0.2181
# Discriminator_loss:0.5790
#
# EPOCH[3] - STEP[170]
# Generator_loss:2.2277
# L1_loss:0.2421
# Discriminator_loss:0.5277
#
# EPOCH[3] - STEP[180]
# Generator_loss:1.1519
# L1_loss:0.2038
# Discriminator_loss:0.5899
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.3929
# L1_loss:0.2328
# Discriminator_loss:0.5600
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.5149
# L1_loss:0.2118
# Discriminator_loss:0.4999
#
# EPOCH[3] - STEP[210]
# Generator_loss:2.6424
# L1_loss:0.1794
# Discriminator_loss:2.2648
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.1067
# L1_loss:0.2094
# Discriminator_loss:0.6050
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.4561
# L1_loss:0.1977
# Discriminator_loss:0.4537
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.7827
# L1_loss:0.1661
# Discriminator_loss:0.5378
#
# EPOCH[3] - STEP[250]
# Generator_loss:3.1134
# L1_loss:0.2191
# Discriminator_loss:0.4228
#
# EPOCH[4] - STEP[10]
# Generator_loss:2.1587
# L1_loss:0.1980
# Discriminator_loss:0.2885
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.2151
# L1_loss:0.1604
# Discriminator_loss:1.2591
#
# EPOCH[4] - STEP[30]
# Generator_loss:0.8363
# L1_loss:0.2144
# Discriminator_loss:0.7551
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.4175
# L1_loss:0.1973
# Discriminator_loss:0.7757
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.8518
# L1_loss:0.2017
# Discriminator_loss:0.6148
#
# EPOCH[4] - STEP[60]
# Generator_loss:2.5377
# L1_loss:0.2018
# Discriminator_loss:0.5986
#
# EPOCH[4] - STEP[70]
# Generator_loss:1.9001
# L1_loss:0.2063
# Discriminator_loss:0.4890
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.4360
# L1_loss:0.2171
# Discriminator_loss:0.5142
#
# EPOCH[4] - STEP[90]
# Generator_loss:0.7323
# L1_loss:0.1974
# Discriminator_loss:1.0279
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.9578
# L1_loss:0.1868
# Discriminator_loss:0.9028
#
# EPOCH[4] - STEP[110]
# Generator_loss:0.4412
# L1_loss:0.2084
# Discriminator_loss:1.4897
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.2358
# L1_loss:0.1660
# Discriminator_loss:0.9505
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.7572
# L1_loss:0.1435
# Discriminator_loss:1.1243
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.9423
# L1_loss:0.2035
# Discriminator_loss:0.4991
#
# EPOCH[4] - STEP[150]
# Generator_loss:2.8356
# L1_loss:0.1755
# Discriminator_loss:1.7718
#
# EPOCH[4] - STEP[160]
# Generator_loss:2.0789
# L1_loss:0.2065
# Discriminator_loss:0.5061
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.3466
# L1_loss:0.1610
# Discriminator_loss:0.6155
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.2038
# L1_loss:0.2108
# Discriminator_loss:0.7543
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.9040
# L1_loss:0.1790
# Discriminator_loss:0.9111
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.7655
# L1_loss:0.2088
# Discriminator_loss:0.9282
#
# EPOCH[4] - STEP[210]
# Generator_loss:2.0824
# L1_loss:0.1722
# Discriminator_loss:1.4599
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.6454
# L1_loss:0.2380
# Discriminator_loss:0.8994
#
# EPOCH[4] - STEP[230]
# Generator_loss:2.6604
# L1_loss:0.2445
# Discriminator_loss:1.4700
#
# EPOCH[4] - STEP[240]
# Generator_loss:2.5954
# L1_loss:0.1996
# Discriminator_loss:0.6800
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.9237
# L1_loss:0.2100
# Discriminator_loss:0.4454
#
# EPOCH[5] - STEP[10]
# Generator_loss:0.5285
# L1_loss:0.1769
# Discriminator_loss:1.4436
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.9418
# L1_loss:0.1580
# Discriminator_loss:1.4795
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.2968
# L1_loss:0.1648
# Discriminator_loss:1.0041
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.4020
# L1_loss:0.1862
# Discriminator_loss:0.8708
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.9672
# L1_loss:0.2085
# Discriminator_loss:0.5460
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.2862
# L1_loss:0.1874
# Discriminator_loss:0.5497
#
# EPOCH[5] - STEP[70]
# Generator_loss:2.2847
# L1_loss:0.1789
# Discriminator_loss:0.4900
#
# EPOCH[5] - STEP[80]
# Generator_loss:0.6949
# L1_loss:0.1745
# Discriminator_loss:1.2903
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.3419
# L1_loss:0.1808
# Discriminator_loss:0.5188
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.3978
# L1_loss:0.1885
# Discriminator_loss:0.7421
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.1556
# L1_loss:0.1935
# Discriminator_loss:1.0820
#
# EPOCH[5] - STEP[120]
# Generator_loss:0.7248
# L1_loss:0.2050
# Discriminator_loss:1.0713
# EPOCH[5] - STEP[130]
# Generator_loss:3.1871
# L1_loss:0.2250
# Discriminator_loss:0.2178
#
# EPOCH[5] - STEP[140]
# Generator_loss:2.8080
# L1_loss:0.1716
# Discriminator_loss:1.5391
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.0240
# L1_loss:0.1673
# Discriminator_loss:0.7805
#
# EPOCH[5] - STEP[160]
# Generator_loss:2.0297
# L1_loss:0.1722
# Discriminator_loss:0.4967
#
# EPOCH[5] - STEP[170]
# Generator_loss:1.5156
# L1_loss:0.2499
# Discriminator_loss:0.9101
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.5955
# L1_loss:0.2006
# Discriminator_loss:0.6916
#
# EPOCH[5] - STEP[190]
# Generator_loss:2.7313
# L1_loss:0.1801
# Discriminator_loss:0.4406
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.7837
# L1_loss:0.2129
# Discriminator_loss:0.7507
#
# EPOCH[5] - STEP[210]
# Generator_loss:2.6885
# L1_loss:0.1676
# Discriminator_loss:1.5952
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.2020
# L1_loss:0.1846
# Discriminator_loss:1.3806
#
# EPOCH[5] - STEP[230]
# Generator_loss:3.1422
# L1_loss:0.1911
# Discriminator_loss:1.0344
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.5953
# L1_loss:0.1940
# Discriminator_loss:0.4886
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.1155
# L1_loss:0.2269
# Discriminator_loss:0.5527
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.7993
# L1_loss:0.1743
# Discriminator_loss:0.6962
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.3862
# L1_loss:0.2096
# Discriminator_loss:0.6165
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.0006
# L1_loss:0.2044
# Discriminator_loss:0.2926
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.2218
# L1_loss:0.2255
# Discriminator_loss:0.9415
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.5446
# L1_loss:0.2423
# Discriminator_loss:0.3623
#
# EPOCH[6] - STEP[60]
# Generator_loss:0.7294
# L1_loss:0.3011
# Discriminator_loss:1.5848
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.2616
# L1_loss:0.1685
# Discriminator_loss:1.0342
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.8613
# L1_loss:0.2234
# Discriminator_loss:0.2973
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.0984
# L1_loss:0.1849
# Discriminator_loss:0.6499
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.4764
# L1_loss:0.1978
# Discriminator_loss:1.2227
#
# EPOCH[6] - STEP[110]
# Generator_loss:2.2274
# L1_loss:0.2281
# Discriminator_loss:0.6503
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.7184
# L1_loss:0.1784
# Discriminator_loss:1.1532
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.7454
# L1_loss:0.1853
# Discriminator_loss:0.4309
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.0579
# L1_loss:0.1631
# Discriminator_loss:0.6533
#
# EPOCH[6] - STEP[150]
# Generator_loss:3.0726
# L1_loss:0.1756
# Discriminator_loss:0.6526
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.7936
# L1_loss:0.1821
# Discriminator_loss:0.3782
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.3646
# L1_loss:0.2039
# Discriminator_loss:1.4977
#
# EPOCH[6] - STEP[180]
# Generator_loss:2.5319
# L1_loss:0.1934
# Discriminator_loss:1.7528
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.6812
# L1_loss:0.1981
# Discriminator_loss:0.9023
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.5799
# L1_loss:0.2047
# Discriminator_loss:1.1322
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.0684
# L1_loss:0.2091
# Discriminator_loss:1.3138
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.0856
# L1_loss:0.1926
# Discriminator_loss:0.6072
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.5397
# L1_loss:0.1852
# Discriminator_loss:0.5472
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.8432
# L1_loss:0.1998
# Discriminator_loss:0.6940
#
# EPOCH[6] - STEP[250]
# Generator_loss:0.6574
# L1_loss:0.2213
# Discriminator_loss:0.9631
#
# EPOCH[7] - STEP[10]
# Generator_loss:3.0995
# L1_loss:0.1746
# Discriminator_loss:1.0194
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.4669
# L1_loss:0.1593
# Discriminator_loss:0.9329
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.0400
# L1_loss:0.1544
# Discriminator_loss:0.8797
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.4740
# L1_loss:0.1739
# Discriminator_loss:0.7682
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.2972
# L1_loss:0.1764
# Discriminator_loss:0.4795
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.9950
# L1_loss:0.2270
# Discriminator_loss:0.5335
#
# EPOCH[7] - STEP[70]
# Generator_loss:2.1697
# L1_loss:0.1721
# Discriminator_loss:0.8827
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.9127
# L1_loss:0.1893
# Discriminator_loss:0.4089
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.2804
# L1_loss:0.2116
# Discriminator_loss:0.5832
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.8947
# L1_loss:0.2157
# Discriminator_loss:0.6362
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.3487
# L1_loss:0.2463
# Discriminator_loss:0.8490
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.8582
# L1_loss:0.2238
# Discriminator_loss:0.2771
#
# EPOCH[7] - STEP[130]
# Generator_loss:0.8837
# L1_loss:0.2238
# Discriminator_loss:0.6698
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.9873
# L1_loss:0.2070
# Discriminator_loss:0.8013
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.1883
# L1_loss:0.1951
# Discriminator_loss:0.5731
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.5574
# L1_loss:0.1784
# Discriminator_loss:0.6638
#
# EPOCH[7] - STEP[170]
# Generator_loss:1.1426
# L1_loss:0.1920
# Discriminator_loss:0.6265
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.1456
# L1_loss:0.2156
# Discriminator_loss:0.6077
# EPOCH[7] - STEP[190]
# Generator_loss:3.3835
# L1_loss:0.2098
# Discriminator_loss:1.4715
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.2457
# L1_loss:0.2272
# Discriminator_loss:0.4649
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.9763
# L1_loss:0.1735
# Discriminator_loss:0.3457
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.4100
# L1_loss:0.1713
# Discriminator_loss:0.6043
#
# EPOCH[7] - STEP[230]
# Generator_loss:2.2632
# L1_loss:0.1545
# Discriminator_loss:1.7058
#
# EPOCH[7] - STEP[240]
# Generator_loss:2.0058
# L1_loss:0.1500
# Discriminator_loss:0.8500
#
# EPOCH[7] - STEP[250]
# Generator_loss:2.4646
# L1_loss:0.1791
# Discriminator_loss:0.7089
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.7607
# L1_loss:0.1935
# Discriminator_loss:0.6573
#
# EPOCH[8] - STEP[20]
# Generator_loss:3.8321
# L1_loss:0.1843
# Discriminator_loss:2.0713
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.0338
# L1_loss:0.1635
# Discriminator_loss:0.6630
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.3571
# L1_loss:0.2048
# Discriminator_loss:1.6691
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.1182
# L1_loss:0.1453
# Discriminator_loss:0.8899
#
# EPOCH[8] - STEP[60]
# Generator_loss:0.4865
# L1_loss:0.1695
# Discriminator_loss:1.1931
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.0453
# L1_loss:0.1753
# Discriminator_loss:2.0648
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.2486
# L1_loss:0.2165
# Discriminator_loss:1.1419
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.3070
# L1_loss:0.1784
# Discriminator_loss:0.5031
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.1103
# L1_loss:0.2042
# Discriminator_loss:0.5551
#
# EPOCH[8] - STEP[110]
# Generator_loss:1.4820
# L1_loss:0.1786
# Discriminator_loss:0.7679
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.4792
# L1_loss:0.1640
# Discriminator_loss:0.4656
#
# EPOCH[8] - STEP[130]
# Generator_loss:0.4821
# L1_loss:0.1957
# Discriminator_loss:1.5435
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.6842
# L1_loss:0.2061
# Discriminator_loss:0.3080
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.9223
# L1_loss:0.1784
# Discriminator_loss:0.7970
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.3711
# L1_loss:0.1884
# Discriminator_loss:0.6964
#
# EPOCH[8] - STEP[170]
# Generator_loss:2.6965
# L1_loss:0.2181
# Discriminator_loss:0.9001
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.4554
# L1_loss:0.1489
# Discriminator_loss:0.7976
#
# EPOCH[8] - STEP[190]
# Generator_loss:0.8661
# L1_loss:0.2318
# Discriminator_loss:0.9545
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.8487
# L1_loss:0.1719
# Discriminator_loss:0.8950
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.7777
# L1_loss:0.1720
# Discriminator_loss:1.3923
#
# EPOCH[8] - STEP[220]
# Generator_loss:2.2274
# L1_loss:0.1670
# Discriminator_loss:0.7512
#
# EPOCH[8] - STEP[230]
# Generator_loss:0.5187
# L1_loss:0.1796
# Discriminator_loss:1.3220
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.8559
# L1_loss:0.2072
# Discriminator_loss:0.5817
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.0526
# L1_loss:0.1722
# Discriminator_loss:1.1001
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.5860
# L1_loss:0.2212
# Discriminator_loss:1.0554
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.3548
# L1_loss:0.2383
# Discriminator_loss:0.5152
#
# EPOCH[9] - STEP[30]
# Generator_loss:2.9228
# L1_loss:0.1774
# Discriminator_loss:0.6147
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.2359
# L1_loss:0.1659
# Discriminator_loss:0.5709
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.4729
# L1_loss:0.1952
# Discriminator_loss:0.7406
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.1292
# L1_loss:0.1414
# Discriminator_loss:0.9896
#
# EPOCH[9] - STEP[70]
# Generator_loss:2.4083
# L1_loss:0.2095
# Discriminator_loss:0.6153
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.6086
# L1_loss:0.1645
# Discriminator_loss:0.5336
#
# EPOCH[9] - STEP[90]
# Generator_loss:2.3308
# L1_loss:0.1923
# Discriminator_loss:0.2023
#
# EPOCH[9] - STEP[100]
# Generator_loss:3.0782
# L1_loss:0.1655
# Discriminator_loss:0.9247
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.0587
# L1_loss:0.1891
# Discriminator_loss:0.5431
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.9805
# L1_loss:0.1739
# Discriminator_loss:0.8423
#
# EPOCH[9] - STEP[130]
# Generator_loss:1.6400
# L1_loss:0.1894
# Discriminator_loss:2.5804
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.6022
# L1_loss:0.1731
# Discriminator_loss:0.6145
#
# EPOCH[9] - STEP[150]
# Generator_loss:3.1891
# L1_loss:0.1808
# Discriminator_loss:1.0884
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.7837
# L1_loss:0.1636
# Discriminator_loss:0.6426
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.2980
# L1_loss:0.1479
# Discriminator_loss:0.4967
#
# EPOCH[9] - STEP[180]
# Generator_loss:2.6212
# L1_loss:0.1668
# Discriminator_loss:0.5336
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.6969
# L1_loss:0.1627
# Discriminator_loss:0.8412
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.9957
# L1_loss:0.1476
# Discriminator_loss:0.8807
#
# EPOCH[9] - STEP[210]
# Generator_loss:3.0013
# L1_loss:0.1831
# Discriminator_loss:0.7079
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.5113
# L1_loss:0.2080
# Discriminator_loss:0.8330
#
# EPOCH[9] - STEP[230]
# Generator_loss:2.0503
# L1_loss:0.1884
# Discriminator_loss:0.7518
#
# EPOCH[9] - STEP[240]
# Generator_loss:2.7025
# L1_loss:0.1800
# Discriminator_loss:0.7873
# EPOCH[9] - STEP[250]
# Generator_loss:2.4967
# L1_loss:0.1979
# Discriminator_loss:0.6091
#
# EPOCH[10] - STEP[10]
# Generator_loss:3.4436
# L1_loss:0.2102
# Discriminator_loss:0.5458
#
# EPOCH[10] - STEP[20]
# Generator_loss:2.0765
# L1_loss:0.1857
# Discriminator_loss:0.4527
#
# EPOCH[10] - STEP[30]
# Generator_loss:2.1388
# L1_loss:0.1439
# Discriminator_loss:2.5655
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.5842
# L1_loss:0.1530
# Discriminator_loss:0.9183
#
# EPOCH[10] - STEP[50]
# Generator_loss:0.3708
# L1_loss:0.1888
# Discriminator_loss:1.4362
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.3680
# L1_loss:0.1871
# Discriminator_loss:0.5463
#
# EPOCH[10] - STEP[70]
# Generator_loss:2.2796
# L1_loss:0.1497
# Discriminator_loss:0.6279
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.3588
# L1_loss:0.2139
# Discriminator_loss:1.4935
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.4282
# L1_loss:0.1987
# Discriminator_loss:0.4995
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.3528
# L1_loss:0.1817
# Discriminator_loss:1.4660
#
# EPOCH[10] - STEP[110]
# Generator_loss:0.7519
# L1_loss:0.1966
# Discriminator_loss:0.8383
#
# EPOCH[10] - STEP[120]
# Generator_loss:0.8197
# L1_loss:0.1765
# Discriminator_loss:0.9519
#
# EPOCH[10] - STEP[130]
# Generator_loss:2.5329
# L1_loss:0.2319
# Discriminator_loss:0.1736
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.1547
# L1_loss:0.1927
# Discriminator_loss:0.2861
#
# EPOCH[10] - STEP[150]
# Generator_loss:0.5030
# L1_loss:0.2011
# Discriminator_loss:1.3286
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.8174
# L1_loss:0.1883
# Discriminator_loss:0.5126
#
# EPOCH[10] - STEP[170]
# Generator_loss:0.9024
# L1_loss:0.1714
# Discriminator_loss:0.8382
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.6198
# L1_loss:0.2115
# Discriminator_loss:0.1880
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.7894
# L1_loss:0.1624
# Discriminator_loss:0.5433
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.3313
# L1_loss:0.1666
# Discriminator_loss:0.5571
#
# EPOCH[10] - STEP[210]
# Generator_loss:1.6998
# L1_loss:0.1787
# Discriminator_loss:0.5438
#
# EPOCH[10] - STEP[220]
# Generator_loss:3.9748
# L1_loss:0.1818
# Discriminator_loss:0.2929
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.3937
# L1_loss:0.1583
# Discriminator_loss:0.7557
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.3522
# L1_loss:0.1701
# Discriminator_loss:0.4402
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.8057
# L1_loss:0.1512
# Discriminator_loss:0.9250

# %% [markdown]
# ## 테스트 및 시각화

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# ---

# %% [markdown]
# # 루브릭

# %% [markdown]
# __1. pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.__
# _(데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.)_

# %% [markdown]
# - 이미지 분할 및 apply_augmentation를 적용하여 데이터셋을 구축하였다.

# %% [markdown]
# __2. pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.__
# _(U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.)_

# %% [markdown]
# - U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행되었다.

# %% [markdown]
# __3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.__
# _(10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.)_

# %% [markdown]
# - 10 epoch 학습 진행했고 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.

# %% [markdown]
# ---

# %% [markdown]
# # 회고

# %% [markdown]
# 1. 프로젝트 진행시 어려웠던 점
# 2. 프로젝트를 진행하면서 알아낸 점 또는 아직 모호한 점
# 3. 루브릭 평가 지표를 맞추기 위해 시도한 점
# 4. 루브릭 평가 지표를 달성하지 못한 이유
# 5. 프로젝트 진행 후 느낀 점 및 다짐

# %% [markdown]
# - Encoder, Decoder, discriminator 각각 여러 레이어를 구성하다보니 헷갈리는 경우가 많았다.
# - 이전 노드부터 GAN을 배울 때마다 어려움이 많았는데 추가적인 공부가 많이 필요할 것 같다.
